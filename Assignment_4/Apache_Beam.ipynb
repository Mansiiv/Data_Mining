# %% [markdown]
# # **Apache Beam**

# %%
# Required installations for Google Colab
# !pip install apache-beam

import apache_beam as beam

# Define custom filter transformation
class FilterHouses(beam.DoFn):
    def process(self, element, threshold=100000):
        if element and 'TotalValue' in element and element['TotalValue']:
            if float(element['TotalValue']) >= threshold:
                yield element

# Define composite transform
class AverageTotalValueByCity(beam.PTransform):
    def expand(self, pcoll):
        return (
            pcoll
            | 'GroupByCity' >> beam.GroupBy('City')
            | 'ComputeAverageTotalValue' >> beam.Map(lambda element: (element[0], sum(float(item['TotalValue']) for item in element[1]) / len(element[1])))
        )

# Define the pipeline with debugging steps
def run_pipeline():
    with beam.Pipeline() as pipeline:
        input_data = (
            pipeline
            | 'ReadCSV' >> beam.io.ReadFromText('/content/sample_data/real-estate-sales-730-days-1.csv', skip_header_lines=1)
            | 'ParseCSV' >> beam.Map(lambda line: dict(zip(['City', 'TotalValue'], line.split(','))))
            | 'PrintParsedData' >> beam.Map(print)  # Debugging step
            | 'FilterByTotalValue' >> beam.ParDo(FilterHouses())
            | 'PrintFilteredData' >> beam.Map(print)  # Debugging step
            | 'AverageByCity' >> AverageTotalValueByCity()
            | 'FormatOutput' >> beam.Map(lambda element: f"{element[0]},{element[1]}")
            | 'WriteToCSV' >> beam.io.WriteToText('/content/output.csv')
        )

run_pipeline()
# Out:
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.10/dist-packages (2.51.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.9.9)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.8.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.59.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.74)
# Requirement already satisfied: numpy<1.25.0,>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.23.5)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.22.3)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.0,!=4.24.1,!=4.24.2,<4.25.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.21.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (9.0.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (5.1)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (2.7.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2023.7.22)
# {'City': '0', 'TotalValue': '30'}
# {'City': '1', 'TotalValue': '50'}
# {'City': '2', 'TotalValue': '58'}
# {'City': '3', 'TotalValue': '66'}
# {'City': '4', 'TotalValue': '78'}
# {'City': '5', 'TotalValue': '79'}
# {'City': '6', 'TotalValue': '94'}
# {'City': '7', 'TotalValue': '94'}
# {'City': '8', 'TotalValue': '98'}
# {'City': '9', 'TotalValue': '98'}
# {'City': '10', 'TotalValue': '103'}
# {'City': '11', 'TotalValue': '127'}
# {'City': '12', 'TotalValue': '142'}
# {'City': '13', 'TotalValue': '165'}
# {'City': '14', 'TotalValue': '189'}
# {'City': '15', 'TotalValue': '192'}
# {'City': '16', 'TotalValue': '200'}
# {'City': '17', 'TotalValue': '203'}
# {'City': '18', 'TotalValue': '235'}
# {'City': '19', 'TotalValue': '235'}
# {'City': '20', 'TotalValue': '258'}
# {'City': '21', 'TotalValue': '263'}
# {'City': '22', 'TotalValue': '328'}
# {'City': '23', 'TotalValue': '364'}
# {'City': '24', 'TotalValue': '415'}
# {'City': '25', 'TotalValue': '467'}
# {'City': '26', 'TotalValue': '489'}
# {'City': '27', 'TotalValue': '11'}
# {'City': '28', 'TotalValue': '35'}
# {'City': '29', 'TotalValue': '56'}
# {'City': '30', 'TotalValue': '56'}
# {'City': '31', 'TotalValue': '58'}
# {'City': '32', 'TotalValue': '60'}
# {'City': '33', 'TotalValue': '75'}
# {'City': '34', 'TotalValue': '78'}
# {'City': '35', 'TotalValue': '79'}
# {'City': '36', 'TotalValue': '79'}
# {'City': '37', 'TotalValue': '12777'}
# {'City': '38', 'TotalValue': '79'}
# {'City': '39', 'TotalValue': '94'}
# {'City': '40', 'TotalValue': '101'}
# {'City': '41', 'TotalValue': '101'}
# {'City': '42', 'TotalValue': '103'}
# {'City': '43', 'TotalValue': '118'}
# {'City': '44', 'TotalValue': '122'}
# {'City': '45', 'TotalValue': '127'}
# {'City': '46', 'TotalValue': '142'}
# {'City': '47', 'TotalValue': '156'}
# {'City': '48', 'TotalValue': '165'}
# {'City': '49', 'TotalValue': '192'}
# {'City': '50', 'TotalValue': '206'}
# {'City': '51', 'TotalValue': '214'}
# {'City': '52', 'TotalValue': '227'}
# {'City': '53', 'TotalValue': '228'}
# {'City': '54', 'TotalValue': '229'}
# {'City': '55', 'TotalValue': '234'}
# {'City': '56', 'TotalValue': '258'}
# {'City': '57', 'TotalValue': '258'}
# {'City': '58', 'TotalValue': '263'}
# {'City': '59', 'TotalValue': '274'}
# {'City': '60', 'TotalValue': '276'}
# {'City': '61', 'TotalValue': '283'}
# {'City': '62', 'TotalValue': '283'}
# {'City': '63', 'TotalValue': '307'}
# {'City': '64', 'TotalValue': '337'}
# {'City': '65', 'TotalValue': '338'}
# {'City': '66', 'TotalValue': '364'}
# {'City': '67', 'TotalValue': '394'}
# {'City': '68', 'TotalValue': '419'}
# {'City': '69', 'TotalValue': '438'}
# {'City': '70', 'TotalValue': '438'}
# {'City': '71', 'TotalValue': '455'}
# {'City': '72', 'TotalValue': '472'}
# {'City': '73', 'TotalValue': '482'}
# {'City': '74', 'TotalValue': '491'}
# {'City': '75', 'TotalValue': '496'}
# {'City': '76', 'TotalValue': '501'}
# {'City': '77', 'TotalValue': '501'}
# {'City': '78', 'TotalValue': '501'}
# {'City': '79', 'TotalValue': '526'}
# {'City': '80', 'TotalValue': '534'}
# {'City': '81', 'TotalValue': '498'}
# {'City': '82', 'TotalValue': '498'}
# {'City': '83', 'TotalValue': '501'}
# {'City': '84', 'TotalValue': '502'}
# {'City': '85', 'TotalValue': '502'}
# {'City': '86', 'TotalValue': '502'}
# {'City': '87', 'TotalValue': '539'}
# {'City': '88', 'TotalValue': '542'}
# {'City': '89', 'TotalValue': '586'}
# {'City': '90', 'TotalValue': '608'}
# {'City': '91', 'TotalValue': '633'}
# {'City': '92', 'TotalValue': '642'}
# {'City': '93', 'TotalValue': '669'}
# {'City': '94', 'TotalValue': '685'}
# {'City': '95', 'TotalValue': '686'}
# {'City': '96', 'TotalValue': '686'}
# {'City': '97', 'TotalValue': '686'}
# {'City': '98', 'TotalValue': '689'}
# {'City': '99', 'TotalValue': '689'}
# {'City': '100', 'TotalValue': '689'}
# {'City': '101', 'TotalValue': '699'}
# {'City': '102', 'TotalValue': '699'}
# {'City': '103', 'TotalValue': '710'}
# {'City': '104', 'TotalValue': '711'}
# {'City': '105', 'TotalValue': '711'}
# {'City': '106', 'TotalValue': '718'}
# {'City': '107', 'TotalValue': '534'}
# {'City': '108', 'TotalValue': '534'}
# {'City': '109', 'TotalValue': '534'}
# {'City': '110', 'TotalValue': '542'}
# {'City': '111', 'TotalValue': '625'}
# {'City': '112', 'TotalValue': '625'}
# {'City': '113', 'TotalValue': '628'}
# {'City': '114', 'TotalValue': '631'}
# {'City': '115', 'TotalValue': '638'}
# {'City': '116', 'TotalValue': '671'}
# {'City': '117', 'TotalValue': '677'}
# {'City': '118', 'TotalValue': '677'}
# {'City': '119', 'TotalValue': '686'}
# {'City': '120', 'TotalValue': '686'}
# {'City': '121', 'TotalValue': '700'}
# {'City': '122', 'TotalValue': '706'}
# {'City': '123', 'TotalValue': '711'}
# {'City': '124', 'TotalValue': '718'}
# {'City': '125', 'TotalValue': '718'}
# {'City': '126', 'TotalValue': '741'}
# {'City': '127', 'TotalValue': '743'}
# {'City': '128', 'TotalValue': '743'}
# {'City': '129', 'TotalValue': '748'}
# {'City': '130', 'TotalValue': '757'}
# {'City': '131', 'TotalValue': '773'}
# {'City': '132', 'TotalValue': '773'}
# {'City': '133', 'TotalValue': '774'}
# {'City': '134', 'TotalValue': '718'}
# {'City': '135', 'TotalValue': '722'}
# {'City': '136', 'TotalValue': '773'}
# {'City': '137', 'TotalValue': '794'}
# {'City': '138', 'TotalValue': '798'}
# {'City': '139', 'TotalValue': '798'}
# {'City': '140', 'TotalValue': '845'}
# {'City': '141', 'TotalValue': '845'}
# {'City': '142', 'TotalValue': '851'}
# {'City': '143', 'TotalValue': '876'}
# {'City': '144', 'TotalValue': '886'}
# {'City': '145', 'TotalValue': '909'}
# {'City': '146', 'TotalValue': '911'}
# {'City': '147', 'TotalValue': '918'}
# {'City': '148', 'TotalValue': '919'}
# {'City': '149', 'TotalValue': '950'}
# {'City': '150', 'TotalValue': '964'}
# {'City': '151', 'TotalValue': '984'}
# {'City': '152', 'TotalValue': '986'}
# {'City': '153', 'TotalValue': '999'}
# {'City': '154', 'TotalValue': '1003'}
# {'City': '155', 'TotalValue': '1027'}
# {'City': '156', 'TotalValue': '1032'}
# {'City': '157', 'TotalValue': '1032'}
# {'City': '158', 'TotalValue': '1037'}
# {'City': '159', 'TotalValue': '1057'}
# {'City': '160', 'TotalValue': '1062'}
# {'City': '161', 'TotalValue': '798'}
# {'City': '162', 'TotalValue': '798'}
# {'City': '163', 'TotalValue': '808'}
# {'City': '164', 'TotalValue': '828'}
# {'City': '165', 'TotalValue': '845'}
# {'City': '166', 'TotalValue': '860'}
# {'City': '167', 'TotalValue': '886'}
# {'City': '168', 'TotalValue': '888'}
# {'City': '169', 'TotalValue': '893'}
# {'City': '170', 'TotalValue': '893'}
# {'City': '171', 'TotalValue': '908'}
# {'City': '172', 'TotalValue': '909'}
# {'City': '173', 'TotalValue': '916'}
# {'City': '174', 'TotalValue': '926'}
# {'City': '175', 'TotalValue': '943'}
# {'City': '176', 'TotalValue': '987'}
# {'City': '177', 'TotalValue': '1003'}
# {'City': '178', 'TotalValue': '1009'}
# {'City': '179', 'TotalValue': '1047'}
# {'City': '180', 'TotalValue': '1062'}
# {'City': '181', 'TotalValue': '1073'}
# {'City': '182', 'TotalValue': '1082'}
# {'City': '183', 'TotalValue': '1096'}
# {'City': '184', 'TotalValue': '1103'}
# {'City': '185', 'TotalValue': '1105'}
# {'City': '186', 'TotalValue': '1156'}
# {'City': '187', 'TotalValue': '1097'}
# {'City': '188', 'TotalValue': '1103'}
# {'City': '189', 'TotalValue': '1113'}
# {'City': '190', 'TotalValue': '1122'}
# {'City': '191', 'TotalValue': '1122'}
# {'City': '192', 'TotalValue': '1144'}
# {'City': '193', 'TotalValue': '1146'}
# {'City': '194', 'TotalValue': '1162'}
# {'City': '195', 'TotalValue': '1165'}
# {'City': '196', 'TotalValue': '1165'}
# {'City': '197', 'TotalValue': '1166'}
# {'City': '198', 'TotalValue': '1185'}
# {'City': '199', 'TotalValue': '1193'}
# {'City': '200', 'TotalValue': '1207'}
# {'City': '201', 'TotalValue': '1212'}
# {'City': '202', 'TotalValue': '1214'}
# {'City': '203', 'TotalValue': '1216'}
# {'City': '204', 'TotalValue': '1235'}
# {'City': '205', 'TotalValue': '1271'}
# {'City': '206', 'TotalValue': '1272'}
# {'City': '207', 'TotalValue': '1275'}
# {'City': '208', 'TotalValue': '1283'}
# {'City': '209', 'TotalValue': '1290'}
# {'City': '210', 'TotalValue': '1300'}
# {'City': '211', 'TotalValue': '1305'}
# {'City': '212', 'TotalValue': '1305'}
# {'City': '213', 'TotalValue': '1156'}
# {'City': '214', 'TotalValue': '1185'}
# {'City': '215', 'TotalValue': '1185'}
# {'City': '216', 'TotalValue': '1186'}
# {'City': '217', 'TotalValue': '1235'}
# {'City': '218', 'TotalValue': '1256'}
# {'City': '219', 'TotalValue': '1262'}
# {'City': '220', 'TotalValue': '1267'}
# {'City': '221', 'TotalValue': '1281'}
# {'City': '222', 'TotalValue': '1290'}
# {'City': '223', 'TotalValue': '1320'}
# {'City': '224', 'TotalValue': '1320'}
# {'City': '225', 'TotalValue': '1327'}
# {'City': '226', 'TotalValue': '1339'}
# {'City': '227', 'TotalValue': '1343'}
# {'City': '228', 'TotalValue': '1356'}
# {'City': '229', 'TotalValue': '1372'}
# {'City': '230', 'TotalValue': '1373'}
# {'City': '231', 'TotalValue': '1396'}
# {'City': '232', 'TotalValue': '1396'}
# {'City': '233', 'TotalValue': '1419'}
# {'City': '234', 'TotalValue': '1421'}
# {'City': '235', 'TotalValue': '1421'}
# {'City': '236', 'TotalValue': '1431'}
# {'City': '237', 'TotalValue': '1465'}
# {'City': '238', 'TotalValue': '1465'}
# {'City': '239', 'TotalValue': '1305'}
# {'City': '240', 'TotalValue': '1329'}
# {'City': '241', 'TotalValue': '1336'}
# {'City': '242', 'TotalValue': '1356'}
# {'City': '243', 'TotalValue': '1372'}
# {'City': '244', 'TotalValue': '1382'}
# {'City': '245', 'TotalValue': '1411'}
# {'City': '246', 'TotalValue': '1418'}
# {'City': '247', 'TotalValue': '1421'}
# {'City': '248', 'TotalValue': '1422'}
# {'City': '249', 'TotalValue': '1448'}
# {'City': '250', 'TotalValue': '1451'}
# {'City': '251', 'TotalValue': '1453'}
# {'City': '252', 'TotalValue': '1488'}
# {'City': '253', 'TotalValue': '1494'}
# {'City': '254', 'TotalValue': '1494'}
# {'City': '255', 'TotalValue': '1494'}
# {'City': '256', 'TotalValue': '1499'}
# {'City': '257', 'TotalValue': '1505'}
# {'City': '258', 'TotalValue': '1505'}
# {'City': '259', 'TotalValue': '1516'}
# {'City': '260', 'TotalValue': '1516'}
# {'City': '261', 'TotalValue': '1518'}
# {'City': '262', 'TotalValue': '1556'}
# {'City': '263', 'TotalValue': '1556'}
# {'City': '264', 'TotalValue': '1569'}
# {'City': '265', 'TotalValue': '1570'}
# {'City': '266', 'TotalValue': '1465'}
# {'City': '267', 'TotalValue': '1469'}
# {'City': '268', 'TotalValue': '1474'}
# {'City': '269', 'TotalValue': '1474'}
# {'City': '270', 'TotalValue': '1474'}
# {'City': '271', 'TotalValue': '1488'}
# {'City': '272', 'TotalValue': '1504'}
# {'City': '273', 'TotalValue': '1518'}
# {'City': '274', 'TotalValue': '1523'}
# {'City': '275', 'TotalValue': '1523'}
# {'City': '276', 'TotalValue': '1571'}
# {'City': '277', 'TotalValue': '1576'}
# {'City': '278', 'TotalValue': '1602'}
# {'City': '279', 'TotalValue': '1621'}
# {'City': '280', 'TotalValue': '1621'}
# {'City': '281', 'TotalValue': '1635'}
# {'City': '282', 'TotalValue': '1641'}
# {'City': '283', 'TotalValue': '1641'}
# {'City': '284', 'TotalValue': '1646'}
# {'City': '285', 'TotalValue': '1646'}
# {'City': '286', 'TotalValue': '1664'}
# {'City': '287', 'TotalValue': '1731'}
# {'City': '288', 'TotalValue': '1741'}
# {'City': '289', 'TotalValue': '1743'}
# {'City': '290', 'TotalValue': '1757'}
# {'City': '291', 'TotalValue': '1768'}
# {'City': '292', 'TotalValue': '1785'}
# {'City': '293', 'TotalValue': '1582'}
# {'City': '294', 'TotalValue': '1592'}
# {'City': '295', 'TotalValue': '1602'}
# {'City': '296', 'TotalValue': '1619'}
# {'City': '297', 'TotalValue': '1619'}
# {'City': '298', 'TotalValue': '1625'}
# {'City': '299', 'TotalValue': '1651'}
# {'City': '300', 'TotalValue': '1720'}
# {'City': '301', 'TotalValue': '1728'}
# {'City': '302', 'TotalValue': '1728'}
# {'City': '303', 'TotalValue': '1752'}
# {'City': '304', 'TotalValue': '1767'}
# {'City': '305', 'TotalValue': '1801'}
# {'City': '306', 'TotalValue': '1819'}
# {'City': '307', 'TotalValue': '1850'}
# {'City': '308', 'TotalValue': '1857'}
# {'City': '309', 'TotalValue': '1884'}
# {'City': '310', 'TotalValue': '1901'}
# {'City': '311', 'TotalValue': '1917'}
# {'City': '312', 'TotalValue': '1922'}
# {'City': '313', 'TotalValue': '1936'}
# {'City': '314', 'TotalValue': '1937'}
# {'City': '315', 'TotalValue': '1937'}
# {'City': '316', 'TotalValue': '1947'}
# {'City': '317', 'TotalValue': '1965'}
# {'City': '318', 'TotalValue': '1987'}
# {'City': '319', 'TotalValue': '2019'}
# {'City': '320', 'TotalValue': '1801'}
# {'City': '321', 'TotalValue': '1801'}
# {'City': '322', 'TotalValue': '1819'}
# {'City': '323', 'TotalValue': '1819'}
# {'City': '324', 'TotalValue': '1834'}
# {'City': '325', 'TotalValue': '1841'}
# {'City': '326', 'TotalValue': '1843'}
# {'City': '327', 'TotalValue': '1866'}
# {'City': '328', 'TotalValue': '1916'}
# {'City': '329', 'TotalValue': '1937'}
# {'City': '330', 'TotalValue': '1951'}
# {'City': '331', 'TotalValue': '1987'}
# {'City': '332', 'TotalValue': '2159'}
# {'City': '333', 'TotalValue': '2202'}
# {'City': '334', 'TotalValue': '2218'}
# {'City': '335', 'TotalValue': '2225'}
# {'City': '336', 'TotalValue': '2243'}
# {'City': '337', 'TotalValue': '2304'}
# {'City': '338', 'TotalValue': '2314'}
# {'City': '339', 'TotalValue': '2351'}
# {'City': '340', 'TotalValue': '2351'}
# {'City': '341', 'TotalValue': '2384'}
# {'City': '342', 'TotalValue': '2387'}
# {'City': '343', 'TotalValue': '2392'}
# {'City': '344', 'TotalValue': '2392'}
# {'City': '345', 'TotalValue': '2399'}
# {'City': '346', 'TotalValue': '2019'}
# {'City': '347', 'TotalValue': '2024'}
# {'City': '348', 'TotalValue': '2037'}
# {'City': '349', 'TotalValue': '2058'}
# {'City': '350', 'TotalValue': '2064'}
# {'City': '351', 'TotalValue': '2065'}
# {'City': '352', 'TotalValue': '2072'}
# {'City': '353', 'TotalValue': '2076'}
# {'City': '354', 'TotalValue': '2077'}
# {'City': '355', 'TotalValue': '2116'}
# {'City': '356', 'TotalValue': '2133'}
# {'City': '357', 'TotalValue': '2139'}
# {'City': '358', 'TotalValue': '2139'}
# {'City': '359', 'TotalValue': '2141'}
# {'City': '360', 'TotalValue': '2147'}
# {'City': '361', 'TotalValue': '2159'}
# {'City': '362', 'TotalValue': '2159'}
# {'City': '363', 'TotalValue': '2202'}
# {'City': '364', 'TotalValue': '2243'}
# {'City': '365', 'TotalValue': '2262'}
# {'City': '366', 'TotalValue': '2313'}
# {'City': '367', 'TotalValue': '2314'}
# {'City': '368', 'TotalValue': '2318'}
# {'City': '369', 'TotalValue': '2323'}
# {'City': '370', 'TotalValue': '2351'}
# {'City': '371', 'TotalValue': '2364'}
# {'City': '372', 'TotalValue': '2400'}
# {'City': '373', 'TotalValue': '2427'}
# {'City': '374', 'TotalValue': '2432'}
# {'City': '375', 'TotalValue': '2438'}
# {'City': '376', 'TotalValue': '2443'}
# {'City': '377', 'TotalValue': '2444'}
# {'City': '378', 'TotalValue': '2444'}
# {'City': '379', 'TotalValue': '2448'}
# {'City': '380', 'TotalValue': '2474'}
# {'City': '381', 'TotalValue': '2474'}
# {'City': '382', 'TotalValue': '2509'}
# {'City': '383', 'TotalValue': '2565'}
# {'City': '384', 'TotalValue': '2570'}
# {'City': '385', 'TotalValue': '2577'}
# {'City': '386', 'TotalValue': '2601'}
# {'City': '387', 'TotalValue': '2624'}
# {'City': '388', 'TotalValue': '2667'}
# {'City': '389', 'TotalValue': '2675'}
# {'City': '390', 'TotalValue': '2712'}
# {'City': '391', 'TotalValue': '2712'}
# {'City': '392', 'TotalValue': '2726'}
# {'City': '393', 'TotalValue': '2731'}
# {'City': '394', 'TotalValue': '2751'}
# {'City': '395', 'TotalValue': '2780'}
# {'City': '396', 'TotalValue': '2780'}
# {'City': '397', 'TotalValue': '2802'}
# {'City': '398', 'TotalValue': '2802'}
# {'City': '399', 'TotalValue': '2391'}
# {'City': '400', 'TotalValue': '2392'}
# {'City': '401', 'TotalValue': '2399'}
# {'City': '402', 'TotalValue': '2425'}
# {'City': '403', 'TotalValue': '2455'}
# {'City': '404', 'TotalValue': '2468'}
# {'City': '405', 'TotalValue': '2473'}
# {'City': '406', 'TotalValue': '2483'}
# {'City': '407', 'TotalValue': '2484'}
# {'City': '408', 'TotalValue': '2495'}
# {'City': '409', 'TotalValue': '2547'}
# {'City': '410', 'TotalValue': '2566'}
# {'City': '411', 'TotalValue': '2566'}
# {'City': '412', 'TotalValue': '2567'}
# {'City': '413', 'TotalValue': '2569'}
# {'City': '414', 'TotalValue': '2570'}
# {'City': '415', 'TotalValue': '2577'}
# {'City': '416', 'TotalValue': '2588'}
# {'City': '417', 'TotalValue': '2589'}
# {'City': '418', 'TotalValue': '2601'}
# {'City': '419', 'TotalValue': '2604'}
# {'City': '420', 'TotalValue': '2609'}
# {'City': '421', 'TotalValue': '2624'}
# {'City': '422', 'TotalValue': '2628'}
# {'City': '423', 'TotalValue': '2658'}
# {'City': '424', 'TotalValue': '2666'}
# {'City': '425', 'TotalValue': '2684'}
# {'City': '426', 'TotalValue': '2804'}
# {'City': '427', 'TotalValue': '2804'}
# {'City': '428', 'TotalValue': '2810'}
# {'City': '429', 'TotalValue': '2811'}
# {'City': '430', 'TotalValue': '2811'}
# {'City': '431', 'TotalValue': '2830'}
# {'City': '432', 'TotalValue': '2855'}
# {'City': '433', 'TotalValue': '2855'}
# {'City': '434', 'TotalValue': '2863'}
# {'City': '435', 'TotalValue': '2882'}
# {'City': '436', 'TotalValue': '2882'}
# {'City': '437', 'TotalValue': '2893'}
# {'City': '438', 'TotalValue': '2934'}
# {'City': '439', 'TotalValue': '2952'}
# {'City': '440', 'TotalValue': '2973'}
# {'City': '441', 'TotalValue': '2983'}
# {'City': '442', 'TotalValue': '2990'}
# {'City': '443', 'TotalValue': '3005'}
# {'City': '444', 'TotalValue': '3017'}
# {'City': '445', 'TotalValue': '3026'}
# {'City': '446', 'TotalValue': '3037'}
# {'City': '447', 'TotalValue': '3038'}
# {'City': '448', 'TotalValue': '3042'}
# {'City': '449', 'TotalValue': '3042'}
# {'City': '450', 'TotalValue': '3051'}
# {'City': '451', 'TotalValue': '3066'}
# {'City': '452', 'TotalValue': '2710'}
# {'City': '453', 'TotalValue': '2712'}
# {'City': '454', 'TotalValue': '2715'}
# {'City': '455', 'TotalValue': '2721'}
# {'City': '456', 'TotalValue': '2721'}
# {'City': '457', 'TotalValue': '2734'}
# {'City': '458', 'TotalValue': '2753'}
# {'City': '459', 'TotalValue': '2763'}
# {'City': '460', 'TotalValue': '2793'}
# {'City': '461', 'TotalValue': '2802'}
# {'City': '462', 'TotalValue': '2810'}
# {'City': '463', 'TotalValue': '2811'}
# {'City': '464', 'TotalValue': '2824'}
# {'City': '465', 'TotalValue': '2840'}
# {'City': '466', 'TotalValue': '2855'}
# {'City': '467', 'TotalValue': '2863'}
# {'City': '468', 'TotalValue': '2867'}
# {'City': '469', 'TotalValue': '2867'}
# {'City': '470', 'TotalValue': '2882'}
# {'City': '471', 'TotalValue': '2888'}
# {'City': '472', 'TotalValue': '2888'}
# {'City': '473', 'TotalValue': '2893'}
# {'City': '474', 'TotalValue': '2916'}
# {'City': '475', 'TotalValue': '2966'}
# {'City': '476', 'TotalValue': '2973'}
# {'City': '477', 'TotalValue': '2976'}
# {'City': '478', 'TotalValue': '3067'}
# {'City': '479', 'TotalValue': '3069'}
# {'City': '480', 'TotalValue': '3073'}
# {'City': '481', 'TotalValue': '3073'}
# {'City': '482', 'TotalValue': '3073'}
# {'City': '483', 'TotalValue': '3082'}
# {'City': '484', 'TotalValue': '3085'}
# {'City': '485', 'TotalValue': '3086'}
# {'City': '486', 'TotalValue': '3102'}
# {'City': '487', 'TotalValue': '3107'}
# {'City': '488', 'TotalValue': '3110'}
# {'City': '489', 'TotalValue': '3120'}
# {'City': '490', 'TotalValue': '3131'}
# {'City': '491', 'TotalValue': '3148'}
# {'City': '492', 'TotalValue': '3149'}
# {'City': '493', 'TotalValue': '3152'}
# {'City': '494', 'TotalValue': '3157'}
# {'City': '495', 'TotalValue': '3157'}
# {'City': '496', 'TotalValue': '3187'}
# {'City': '497', 'TotalValue': '3194'}
# {'City': '498', 'TotalValue': '3196'}
# {'City': '499', 'TotalValue': '3208'}
# {'City': '500', 'TotalValue': '3210'}
# {'City': '501', 'TotalValue': '3212'}
# {'City': '502', 'TotalValue': '3233'}
# {'City': '503', 'TotalValue': '3234'}
# {'City': '504', 'TotalValue': '3007'}
# {'City': '505', 'TotalValue': '3017'}
# {'City': '506', 'TotalValue': '3019'}
# {'City': '507', 'TotalValue': '3026'}
# {'City': '508', 'TotalValue': '3026'}
# {'City': '509', 'TotalValue': '3026'}
# {'City': '510', 'TotalValue': '3045'}
# {'City': '511', 'TotalValue': '3049'}
# {'City': '512', 'TotalValue': '3061'}
# {'City': '513', 'TotalValue': '3066'}
# {'City': '514', 'TotalValue': '3082'}
# {'City': '515', 'TotalValue': '3085'}
# {'City': '516', 'TotalValue': '3086'}
# {'City': '517', 'TotalValue': '3094'}
# {'City': '518', 'TotalValue': '3095'}
# {'City': '519', 'TotalValue': '3102'}
# {'City': '520', 'TotalValue': '3110'}
# {'City': '521', 'TotalValue': '3131'}
# {'City': '522', 'TotalValue': '3131'}
# {'City': '523', 'TotalValue': '3148'}
# {'City': '524', 'TotalValue': '3157'}
# {'City': '525', 'TotalValue': '3157'}
# {'City': '526', 'TotalValue': '3181'}
# {'City': '527', 'TotalValue': '3185'}
# {'City': '528', 'TotalValue': '3196'}
# {'City': '529', 'TotalValue': '3218'}
# {'City': '530', 'TotalValue': '3251'}
# {'City': '531', 'TotalValue': '3280'}
# {'City': '532', 'TotalValue': '3288'}
# {'City': '533', 'TotalValue': '3301'}
# {'City': '534', 'TotalValue': '3312'}
# {'City': '535', 'TotalValue': '3327'}
# {'City': '536', 'TotalValue': '3338'}
# {'City': '537', 'TotalValue': '3338'}
# {'City': '538', 'TotalValue': '3340'}
# {'City': '539', 'TotalValue': '3341'}
# {'City': '540', 'TotalValue': '3348'}
# {'City': '541', 'TotalValue': '3365'}
# {'City': '542', 'TotalValue': '3365'}
# {'City': '543', 'TotalValue': '3367'}
# {'City': '544', 'TotalValue': '3410'}
# {'City': '545', 'TotalValue': '3445'}
# {'City': '546', 'TotalValue': '3445'}
# {'City': '547', 'TotalValue': '3449'}
# {'City': '548', 'TotalValue': '3460'}
# {'City': '549', 'TotalValue': '3464'}
# {'City': '550', 'TotalValue': '3466'}
# {'City': '551', 'TotalValue': '3466'}
# {'City': '552', 'TotalValue': '3468'}
# {'City': '553', 'TotalValue': '3472'}
# {'City': '554', 'TotalValue': '3473'}
# {'City': '555', 'TotalValue': '3473'}
# {'City': '556', 'TotalValue': '3233'}
# {'City': '557', 'TotalValue': '3234'}
# {'City': '558', 'TotalValue': '3238'}
# {'City': '559', 'TotalValue': '3251'}
# {'City': '560', 'TotalValue': '3275'}
# {'City': '561', 'TotalValue': '3282'}
# {'City': '562', 'TotalValue': '3282'}
# {'City': '563', 'TotalValue': '3297'}
# {'City': '564', 'TotalValue': '3301'}
# {'City': '565', 'TotalValue': '3305'}
# {'City': '566', 'TotalValue': '3312'}
# {'City': '567', 'TotalValue': '3338'}
# {'City': '568', 'TotalValue': '3346'}
# {'City': '569', 'TotalValue': '3357'}
# {'City': '570', 'TotalValue': '3365'}
# {'City': '571', 'TotalValue': '3366'}
# {'City': '572', 'TotalValue': '3440'}
# {'City': '573', 'TotalValue': '3453'}
# {'City': '574', 'TotalValue': '3464'}
# {'City': '575', 'TotalValue': '3466'}
# {'City': '576', 'TotalValue': '3472'}
# {'City': '577', 'TotalValue': '3479'}
# {'City': '578', 'TotalValue': '3481'}
# {'City': '579', 'TotalValue': '3502'}
# {'City': '580', 'TotalValue': '3515'}
# {'City': '581', 'TotalValue': '3520'}
# {'City': '582', 'TotalValue': '3488'}
# {'City': '583', 'TotalValue': '3511'}
# {'City': '584', 'TotalValue': '3513'}
# {'City': '585', 'TotalValue': '3513'}
# {'City': '586', 'TotalValue': '3515'}
# {'City': '587', 'TotalValue': '3520'}
# {'City': '588', 'TotalValue': '3524'}
# {'City': '589', 'TotalValue': '3527'}
# {'City': '590', 'TotalValue': '3535'}
# {'City': '591', 'TotalValue': '3559'}
# {'City': '592', 'TotalValue': '3559'}
# {'City': '593', 'TotalValue': '3562'}
# {'City': '594', 'TotalValue': '3563'}
# {'City': '595', 'TotalValue': '3563'}
# {'City': '596', 'TotalValue': '3563'}
# {'City': '597', 'TotalValue': '3566'}
# {'City': '598', 'TotalValue': '3591'}
# {'City': '599', 'TotalValue': '3591'}
# {'City': '600', 'TotalValue': '3596'}
# {'City': '601', 'TotalValue': '3602'}
# {'City': '602', 'TotalValue': '3614'}
# {'City': '603', 'TotalValue': '3614'}
# {'City': '604', 'TotalValue': '3627'}
# {'City': '605', 'TotalValue': '3627'}
# {'City': '606', 'TotalValue': '3629'}
# {'City': '607', 'TotalValue': '3704'}
# {'City': '608', 'TotalValue': '3525'}
# {'City': '609', 'TotalValue': '3551'}
# {'City': '610', 'TotalValue': '3562'}
# {'City': '611', 'TotalValue': '3563'}
# {'City': '612', 'TotalValue': '3582'}
# {'City': '613', 'TotalValue': '3596'}
# {'City': '614', 'TotalValue': '3614'}
# {'City': '615', 'TotalValue': '3614'}
# {'City': '616', 'TotalValue': '3632'}
# {'City': '617', 'TotalValue': '3632'}
# {'City': '618', 'TotalValue': '3696'}
# {'City': '619', 'TotalValue': '3704'}
# {'City': '620', 'TotalValue': '3726'}
# {'City': '621', 'TotalValue': '3737'}
# {'City': '622', 'TotalValue': '3742'}
# {'City': '623', 'TotalValue': '3742'}
# {'City': '624', 'TotalValue': '3742'}
# {'City': '625', 'TotalValue': '3758'}
# {'City': '626', 'TotalValue': '3766'}
# {'City': '627', 'TotalValue': '3767'}
# {'City': '628', 'TotalValue': '3768'}
# {'City': '629', 'TotalValue': '3788'}
# {'City': '630', 'TotalValue': '3802'}
# {'City': '631', 'TotalValue': '3812'}
# {'City': '632', 'TotalValue': '3820'}
# {'City': '633', 'TotalValue': '3848'}
# {'City': '634', 'TotalValue': '3759'}
# {'City': '635', 'TotalValue': '3759'}
# {'City': '636', 'TotalValue': '3765'}
# {'City': '637', 'TotalValue': '3766'}
# {'City': '638', 'TotalValue': '3785'}
# {'City': '639', 'TotalValue': '3801'}
# {'City': '640', 'TotalValue': '3813'}
# {'City': '641', 'TotalValue': '3820'}
# {'City': '642', 'TotalValue': '3857'}
# {'City': '643', 'TotalValue': '3864'}
# {'City': '644', 'TotalValue': '3902'}
# {'City': '645', 'TotalValue': '3918'}
# {'City': '646', 'TotalValue': '3922'}
# {'City': '647', 'TotalValue': '3922'}
# {'City': '648', 'TotalValue': '3922'}
# {'City': '649', 'TotalValue': '3923'}
# {'City': '650', 'TotalValue': '3925'}
# {'City': '651', 'TotalValue': '3943'}
# {'City': '652', 'TotalValue': '3951'}
# {'City': '653', 'TotalValue': '3951'}
# {'City': '654', 'TotalValue': '3955'}
# {'City': '655', 'TotalValue': '3955'}
# {'City': '656', 'TotalValue': '3956'}
# {'City': '657', 'TotalValue': '3984'}
# {'City': '658', 'TotalValue': '3993'}
# {'City': '659', 'TotalValue': '4015'}
# {'City': '660', 'TotalValue': '4015'}
# {'City': '661', 'TotalValue': '3876'}
# {'City': '662', 'TotalValue': '3885'}
# {'City': '663', 'TotalValue': '3920'}
# {'City': '664', 'TotalValue': '3920'}
# {'City': '665', 'TotalValue': '3922'}
# {'City': '666', 'TotalValue': '3931'}
# {'City': '667', 'TotalValue': '3931'}
# {'City': '668', 'TotalValue': '3943'}
# {'City': '669', 'TotalValue': '3948'}
# {'City': '670', 'TotalValue': '3948'}
# {'City': '671', 'TotalValue': '3956'}
# {'City': '672', 'TotalValue': '3956'}
# {'City': '673', 'TotalValue': '3972'}
# {'City': '674', 'TotalValue': '3977'}
# {'City': '675', 'TotalValue': '3985'}
# {'City': '676', 'TotalValue': '3993'}
# {'City': '677', 'TotalValue': '4028'}
# {'City': '678', 'TotalValue': '4072'}
# {'City': '679', 'TotalValue': '4078'}
# {'City': '680', 'TotalValue': '4085'}
# {'City': '681', 'TotalValue': '4085'}
# {'City': '682', 'TotalValue': '4094'}
# {'City': '683', 'TotalValue': '4098'}
# {'City': '684', 'TotalValue': '4111'}
# {'City': '685', 'TotalValue': '4112'}
# {'City': '686', 'TotalValue': '4124'}
# {'City': '687', 'TotalValue': '4015'}
# {'City': '688', 'TotalValue': '4021'}
# {'City': '689', 'TotalValue': '4073'}
# {'City': '690', 'TotalValue': '4073'}
# {'City': '691', 'TotalValue': '4073'}
# {'City': '692', 'TotalValue': '4078'}
# {'City': '693', 'TotalValue': '4078'}
# {'City': '694', 'TotalValue': '4085'}
# {'City': '695', 'TotalValue': '4097'}
# {'City': '696', 'TotalValue': '4100'}
# {'City': '697', 'TotalValue': '4115'}
# {'City': '698', 'TotalValue': '4124'}
# {'City': '699', 'TotalValue': '4127'}
# {'City': '700', 'TotalValue': '4148'}
# {'City': '701', 'TotalValue': '4688'}
# {'City': '702', 'TotalValue': '4165'}
# {'City': '703', 'TotalValue': '4166'}
# {'City': '704', 'TotalValue': '4194'}
# {'City': '705', 'TotalValue': '4194'}
# {'City': '706', 'TotalValue': '4227'}
# {'City': '707', 'TotalValue': '4256'}
# {'City': '708', 'TotalValue': '4264'}
# {'City': '709', 'TotalValue': '4336'}
# {'City': '710', 'TotalValue': '4336'}
# {'City': '711', 'TotalValue': '4341'}
# {'City': '712', 'TotalValue': '4358'}
# {'City': '713', 'TotalValue': '4364'}
# {'City': '714', 'TotalValue': '4128'}
# {'City': '715', 'TotalValue': '4150'}
# {'City': '716', 'TotalValue': '4151'}
# {'City': '717', 'TotalValue': '4151'}
# {'City': '718', 'TotalValue': '4157'}
# {'City': '719', 'TotalValue': '4166'}
# {'City': '720', 'TotalValue': '4173'}
# {'City': '721', 'TotalValue': '4174'}
# {'City': '722', 'TotalValue': '4194'}
# {'City': '723', 'TotalValue': '4200'}
# {'City': '724', 'TotalValue': '4226'}
# {'City': '725', 'TotalValue': '4248'}
# {'City': '726', 'TotalValue': '4264'}
# {'City': '727', 'TotalValue': '4264'}
# {'City': '728', 'TotalValue': '4301'}
# {'City': '729', 'TotalValue': '4330'}
# {'City': '730', 'TotalValue': '4339'}
# {'City': '731', 'TotalValue': '4351'}
# {'City': '732', 'TotalValue': '4364'}
# {'City': '733', 'TotalValue': '4378'}
# {'City': '734', 'TotalValue': '4481'}
# {'City': '735', 'TotalValue': '4487'}
# {'City': '736', 'TotalValue': '4505'}
# {'City': '737', 'TotalValue': '4510'}
# {'City': '738', 'TotalValue': '4510'}
# {'City': '739', 'TotalValue': '4543'}
# {'City': '740', 'TotalValue': '4408'}
# {'City': '741', 'TotalValue': '4474'}
# {'City': '742', 'TotalValue': '4476'}
# {'City': '743', 'TotalValue': '4480'}
# {'City': '744', 'TotalValue': '4488'}
# {'City': '745', 'TotalValue': '4510'}
# {'City': '746', 'TotalValue': '4510'}
# {'City': '747', 'TotalValue': '4540'}
# {'City': '748', 'TotalValue': '4543'}
# {'City': '749', 'TotalValue': '4544'}
# {'City': '750', 'TotalValue': '4559'}
# {'City': '751', 'TotalValue': '4571'}
# {'City': '752', 'TotalValue': '4621'}
# {'City': '753', 'TotalValue': '4622'}
# {'City': '754', 'TotalValue': '4624'}
# {'City': '755', 'TotalValue': '4626'}
# {'City': '756', 'TotalValue': '4628'}
# {'City': '757', 'TotalValue': '4633'}
# {'City': '758', 'TotalValue': '4653'}
# {'City': '759', 'TotalValue': '4653'}
# {'City': '760', 'TotalValue': '4669'}
# {'City': '761', 'TotalValue': '4681'}
# {'City': '762', 'TotalValue': '4688'}
# {'City': '763', 'TotalValue': '4698'}
# {'City': '764', 'TotalValue': '4731'}
# {'City': '765', 'TotalValue': '4753'}
# {'City': '766', 'TotalValue': '4571'}
# {'City': '767', 'TotalValue': '4587'}
# {'City': '768', 'TotalValue': '4599'}
# {'City': '769', 'TotalValue': '4627'}
# {'City': '770', 'TotalValue': '4627'}
# {'City': '771', 'TotalValue': '4641'}
# {'City': '772', 'TotalValue': '4653'}
# {'City': '773', 'TotalValue': '4653'}
# {'City': '774', 'TotalValue': '4681'}
# {'City': '775', 'TotalValue': '4685'}
# {'City': '776', 'TotalValue': '4693'}
# {'City': '777', 'TotalValue': '4705'}
# {'City': '778', 'TotalValue': '4706'}
# {'City': '779', 'TotalValue': '4715'}
# {'City': '780', 'TotalValue': '4759'}
# {'City': '781', 'TotalValue': '4762'}
# {'City': '782', 'TotalValue': '4779'}
# {'City': '783', 'TotalValue': '4793'}
# {'City': '784', 'TotalValue': '4795'}
# {'City': '785', 'TotalValue': '4797'}
# {'City': '786', 'TotalValue': '4813'}
# {'City': '787', 'TotalValue': '4813'}
# {'City': '788', 'TotalValue': '4849'}
# {'City': '789', 'TotalValue': '4850'}
# {'City': '790', 'TotalValue': '4864'}
# {'City': '791', 'TotalValue': '4865'}
# {'City': '792', 'TotalValue': '4756'}
# {'City': '793', 'TotalValue': '4760'}
# {'City': '794', 'TotalValue': '4772'}
# {'City': '795', 'TotalValue': '4778'}
# {'City': '796', 'TotalValue': '4781'}
# {'City': '797', 'TotalValue': '4794'}
# {'City': '798', 'TotalValue': '4796'}
# {'City': '799', 'TotalValue': '4806'}
# {'City': '800', 'TotalValue': '4806'}
# {'City': '801', 'TotalValue': '4813'}
# {'City': '802', 'TotalValue': '4850'}
# {'City': '803', 'TotalValue': '4855'}
# {'City': '804', 'TotalValue': '4859'}
# {'City': '805', 'TotalValue': '4867'}
# {'City': '806', 'TotalValue': '4904'}
# {'City': '807', 'TotalValue': '4920'}
# {'City': '808', 'TotalValue': '4926'}
# {'City': '809', 'TotalValue': '4934'}
# {'City': '810', 'TotalValue': '4991'}
# {'City': '811', 'TotalValue': '5018'}
# {'City': '812', 'TotalValue': '5019'}
# {'City': '813', 'TotalValue': '5052'}
# {'City': '814', 'TotalValue': '5058'}
# {'City': '815', 'TotalValue': '5071'}
# {'City': '816', 'TotalValue': '5076'}
# {'City': '817', 'TotalValue': '5100'}
# {'City': '818', 'TotalValue': '5123'}
# {'City': '819', 'TotalValue': '4866'}
# {'City': '820', 'TotalValue': '4867'}
# {'City': '821', 'TotalValue': '4877'}
# {'City': '822', 'TotalValue': '4901'}
# {'City': '823', 'TotalValue': '4902'}
# {'City': '824', 'TotalValue': '4934'}
# {'City': '825', 'TotalValue': '4956'}
# {'City': '826', 'TotalValue': '4961'}
# {'City': '827', 'TotalValue': '4963'}
# {'City': '828', 'TotalValue': '4977'}
# {'City': '829', 'TotalValue': '4986'}
# {'City': '830', 'TotalValue': '4994'}
# {'City': '831', 'TotalValue': '5011'}
# {'City': '832', 'TotalValue': '5019'}
# {'City': '833', 'TotalValue': '5019'}
# {'City': '834', 'TotalValue': '5024'}
# {'City': '835', 'TotalValue': '5060'}
# {'City': '836', 'TotalValue': '5062'}
# {'City': '837', 'TotalValue': '5084'}
# {'City': '838', 'TotalValue': '5100'}
# {'City': '839', 'TotalValue': '5102'}
# {'City': '840', 'TotalValue': '5139'}
# {'City': '841', 'TotalValue': '5147'}
# {'City': '842', 'TotalValue': '5152'}
# {'City': '843', 'TotalValue': '5154'}
# {'City': '844', 'TotalValue': '5156'}
# {'City': '845', 'TotalValue': '5172'}
# {'City': '846', 'TotalValue': '5127'}
# {'City': '847', 'TotalValue': '5141'}
# {'City': '848', 'TotalValue': '5142'}
# {'City': '849', 'TotalValue': '5151'}
# {'City': '850', 'TotalValue': '5158'}
# {'City': '851', 'TotalValue': '5164'}
# {'City': '852', 'TotalValue': '5167'}
# {'City': '853', 'TotalValue': '5245'}
# {'City': '854', 'TotalValue': '5259'}
# {'City': '855', 'TotalValue': '5262'}
# {'City': '856', 'TotalValue': '5262'}
# {'City': '857', 'TotalValue': '5266'}
# {'City': '858', 'TotalValue': '5287'}
# {'City': '859', 'TotalValue': '5288'}
# {'City': '860', 'TotalValue': '5292'}
# {'City': '861', 'TotalValue': '5294'}
# {'City': '862', 'TotalValue': '5307'}
# {'City': '863', 'TotalValue': '5307'}
# {'City': '864', 'TotalValue': '5308'}
# {'City': '865', 'TotalValue': '5308'}
# {'City': '866', 'TotalValue': '5311'}
# {'City': '867', 'TotalValue': '5317'}
# {'City': '868', 'TotalValue': '5320'}
# {'City': '869', 'TotalValue': '5325'}
# {'City': '870', 'TotalValue': '5325'}
# {'City': '871', 'TotalValue': '5326'}
# {'City': '872', 'TotalValue': '5190'}
# {'City': '873', 'TotalValue': '5246'}
# {'City': '874', 'TotalValue': '5246'}
# {'City': '875', 'TotalValue': '5247'}
# {'City': '876', 'TotalValue': '5263'}
# {'City': '877', 'TotalValue': '5263'}
# {'City': '878', 'TotalValue': '5266'}
# {'City': '879', 'TotalValue': '5277'}
# {'City': '880', 'TotalValue': '5286'}
# {'City': '881', 'TotalValue': '5287'}
# {'City': '882', 'TotalValue': '5288'}
# {'City': '883', 'TotalValue': '5295'}
# {'City': '884', 'TotalValue': '5300'}
# {'City': '885', 'TotalValue': '5308'}
# {'City': '886', 'TotalValue': '5319'}
# {'City': '887', 'TotalValue': '5319'}
# {'City': '888', 'TotalValue': '5326'}
# {'City': '889', 'TotalValue': '5358'}
# {'City': '890', 'TotalValue': '5371'}
# {'City': '891', 'TotalValue': '5394'}
# {'City': '892', 'TotalValue': '5404'}
# {'City': '893', 'TotalValue': '5404'}
# {'City': '894', 'TotalValue': '5421'}
# {'City': '895', 'TotalValue': '5436'}
# {'City': '896', 'TotalValue': '5443'}
# {'City': '897', 'TotalValue': '5448'}
# {'City': '898', 'TotalValue': '5356'}
# {'City': '899', 'TotalValue': '5377'}
# {'City': '900', 'TotalValue': '5379'}
# {'City': '901', 'TotalValue': '5382'}
# {'City': '902', 'TotalValue': '5394'}
# {'City': '903', 'TotalValue': '5395'}
# {'City': '904', 'TotalValue': '5395'}
# {'City': '905', 'TotalValue': '5396'}
# {'City': '906', 'TotalValue': '5396'}
# {'City': '907', 'TotalValue': '5402'}
# {'City': '908', 'TotalValue': '5442'}
# {'City': '909', 'TotalValue': '5450'}
# {'City': '910', 'TotalValue': '5482'}
# {'City': '911', 'TotalValue': '5483'}
# {'City': '912', 'TotalValue': '5484'}
# {'City': '913', 'TotalValue': '5525'}
# {'City': '914', 'TotalValue': '5532'}
# {'City': '915', 'TotalValue': '5532'}
# {'City': '916', 'TotalValue': '5535'}
# {'City': '917', 'TotalValue': '5573'}
# {'City': '918', 'TotalValue': '5610'}
# {'City': '919', 'TotalValue': '5611'}
# {'City': '920', 'TotalValue': '5619'}
# {'City': '921', 'TotalValue': '5625'}
# {'City': '922', 'TotalValue': '5630'}
# {'City': '923', 'TotalValue': '5655'}
# {'City': '924', 'TotalValue': '5660'}
# {'City': '925', 'TotalValue': '5660'}
# {'City': '926', 'TotalValue': '5660'}
# {'City': '927', 'TotalValue': '5666'}
# {'City': '928', 'TotalValue': '5668'}
# {'City': '929', 'TotalValue': '5671'}
# {'City': '930', 'TotalValue': '5671'}
# {'City': '931', 'TotalValue': '5688'}
# {'City': '932', 'TotalValue': '5692'}
# {'City': '933', 'TotalValue': '5707'}
# {'City': '934', 'TotalValue': '5708'}
# {'City': '935', 'TotalValue': '5735'}
# {'City': '936', 'TotalValue': '5736'}
# {'City': '937', 'TotalValue': '5743'}
# {'City': '938', 'TotalValue': '5750'}
# {'City': '939', 'TotalValue': '5750'}
# {'City': '940', 'TotalValue': '5756'}
# {'City': '941', 'TotalValue': '5758'}
# {'City': '942', 'TotalValue': '5758'}
# {'City': '943', 'TotalValue': '5769'}
# {'City': '944', 'TotalValue': '5792'}
# {'City': '945', 'TotalValue': '5841'}
# {'City': '946', 'TotalValue': '5882'}
# {'City': '947', 'TotalValue': '5887'}
# {'City': '948', 'TotalValue': '5887'}
# {'City': '949', 'TotalValue': '5907'}
# {'City': '950', 'TotalValue': '5925'}
# {'City': '951', 'TotalValue': '5946'}
# {'City': '952', 'TotalValue': '5959'}
# {'City': '953', 'TotalValue': '5973'}
# {'City': '954', 'TotalValue': '6018'}
# {'City': '955', 'TotalValue': '6033'}
# {'City': '956', 'TotalValue': '6042'}
# {'City': '957', 'TotalValue': '6053'}
# {'City': '958', 'TotalValue': '6065'}
# {'City': '959', 'TotalValue': '6074'}
# {'City': '960', 'TotalValue': '6089'}
# {'City': '961', 'TotalValue': '6130'}
# {'City': '962', 'TotalValue': '6130'}
# {'City': '963', 'TotalValue': '6130'}
# {'City': '964', 'TotalValue': '6130'}
# {'City': '965', 'TotalValue': '6142'}
# {'City': '966', 'TotalValue': '6185'}
# {'City': '967', 'TotalValue': '6185'}
# {'City': '968', 'TotalValue': '6185'}
# {'City': '969', 'TotalValue': '6207'}
# {'City': '970', 'TotalValue': '6211'}
# {'City': '971', 'TotalValue': '6234'}
# {'City': '972', 'TotalValue': '6259'}
# {'City': '973', 'TotalValue': '6274'}
# {'City': '974', 'TotalValue': '6274'}
# {'City': '975', 'TotalValue': '6283'}
# {'City': '976', 'TotalValue': '6285'}
# {'City': '977', 'TotalValue': '6286'}
# {'City': '978', 'TotalValue': '6300'}
# {'City': '979', 'TotalValue': '6407'}
# {'City': '980', 'TotalValue': '6407'}
# {'City': '981', 'TotalValue': '6413'}
# {'City': '982', 'TotalValue': '6423'}
# {'City': '983', 'TotalValue': '6431'}
# {'City': '984', 'TotalValue': '6442'}
# {'City': '985', 'TotalValue': '6450'}
# {'City': '986', 'TotalValue': '6461'}
# {'City': '987', 'TotalValue': '6500'}
# {'City': '988', 'TotalValue': '6500'}
# {'City': '989', 'TotalValue': '6539'}
# {'City': '990', 'TotalValue': '6560'}
# {'City': '991', 'TotalValue': '6563'}
# {'City': '992', 'TotalValue': '6619'}
# {'City': '993', 'TotalValue': '6621'}
# {'City': '994', 'TotalValue': '6647'}
# {'City': '995', 'TotalValue': '6711'}
# {'City': '996', 'TotalValue': '6711'}
# {'City': '997', 'TotalValue': '6711'}
# {'City': '998', 'TotalValue': '6711'}
# {'City': '999', 'TotalValue': '6714'}
# {'City': '1000', 'TotalValue': '6766'}
# {'City': '1001', 'TotalValue': '6777'}
# {'City': '1002', 'TotalValue': '6780'}
# {'City': '1003', 'TotalValue': '6786'}
# {'City': '1004', 'TotalValue': '6791'}
# {'City': '1005', 'TotalValue': '6795'}
# {'City': '1006', 'TotalValue': '6808'}
# {'City': '1007', 'TotalValue': '6808'}
# {'City': '1008', 'TotalValue': '6823'}
# {'City': '1009', 'TotalValue': '6839'}
# {'City': '1010', 'TotalValue': '6842'}
# {'City': '1011', 'TotalValue': '6842'}
# {'City': '1012', 'TotalValue': '6852'}
# {'City': '1013', 'TotalValue': '6852'}
# {'City': '1014', 'TotalValue': '6885'}
# {'City': '1015', 'TotalValue': '6885'}
# {'City': '1016', 'TotalValue': '6894'}
# {'City': '1017', 'TotalValue': '6909'}
# {'City': '1018', 'TotalValue': '6909'}
# {'City': '1019', 'TotalValue': '6912'}
# {'City': '1020', 'TotalValue': '6914'}
# {'City': '1021', 'TotalValue': '6928'}
# {'City': '1022', 'TotalValue': '6930'}
# {'City': '1023', 'TotalValue': '6940'}
# {'City': '1024', 'TotalValue': '6954'}
# {'City': '1025', 'TotalValue': '6970'}
# {'City': '1026', 'TotalValue': '6981'}
# {'City': '1027', 'TotalValue': '6982'}
# {'City': '1028', 'TotalValue': '6982'}
# {'City': '1029', 'TotalValue': '6989'}
# {'City': '1030', 'TotalValue': '6989'}
# {'City': '1031', 'TotalValue': '7012'}
# {'City': '1032', 'TotalValue': '7022'}
# {'City': '1033', 'TotalValue': '7055'}
# {'City': '1034', 'TotalValue': '7055'}
# {'City': '1035', 'TotalValue': '7104'}
# {'City': '1036', 'TotalValue': '7106'}
# {'City': '1037', 'TotalValue': '7125'}
# {'City': '1038', 'TotalValue': '7148'}
# {'City': '1039', 'TotalValue': '7168'}
# {'City': '1040', 'TotalValue': '7182'}
# {'City': '1041', 'TotalValue': '7184'}
# {'City': '1042', 'TotalValue': '7195'}
# {'City': '1043', 'TotalValue': '7219'}
# {'City': '1044', 'TotalValue': '7238'}
# {'City': '1045', 'TotalValue': '7284'}
# {'City': '1046', 'TotalValue': '7302'}
# {'City': '1047', 'TotalValue': '7316'}
# {'City': '1048', 'TotalValue': '7354'}
# {'City': '1049', 'TotalValue': '7361'}
# {'City': '1050', 'TotalValue': '7370'}
# {'City': '1051', 'TotalValue': '7370'}
# {'City': '1052', 'TotalValue': '7387'}
# {'City': '1053', 'TotalValue': '7394'}
# {'City': '1054', 'TotalValue': '7395'}
# {'City': '1055', 'TotalValue': '7398'}
# {'City': '1056', 'TotalValue': '7398'}
# {'City': '1057', 'TotalValue': '7398'}
# {'City': '1058', 'TotalValue': '7398'}
# {'City': '1059', 'TotalValue': '5450'}
# {'City': '1060', 'TotalValue': '5480'}
# {'City': '1061', 'TotalValue': '5486'}
# {'City': '1062', 'TotalValue': '5492'}
# {'City': '1063', 'TotalValue': '5503'}
# {'City': '1064', 'TotalValue': '5509'}
# {'City': '1065', 'TotalValue': '5524'}
# {'City': '1066', 'TotalValue': '5524'}
# {'City': '1067', 'TotalValue': '5539'}
# {'City': '1068', 'TotalValue': '5546'}
# {'City': '1069', 'TotalValue': '5546'}
# {'City': '1070', 'TotalValue': '5570'}
# {'City': '1071', 'TotalValue': '5617'}
# {'City': '1072', 'TotalValue': '5617'}
# {'City': '1073', 'TotalValue': '5617'}
# {'City': '1074', 'TotalValue': '5617'}
# {'City': '1075', 'TotalValue': '5636'}
# {'City': '1076', 'TotalValue': '5636'}
# {'City': '1077', 'TotalValue': '5636'}
# {'City': '1078', 'TotalValue': '5636'}
# {'City': '1079', 'TotalValue': '5656'}
# {'City': '1080', 'TotalValue': '5662'}
# {'City': '1081', 'TotalValue': '5677'}
# {'City': '1082', 'TotalValue': '5682'}
# {'City': '1083', 'TotalValue': '5691'}
# {'City': '1084', 'TotalValue': '5716'}
# {'City': '1085', 'TotalValue': '7401'}
# {'City': '1086', 'TotalValue': '7419'}
# {'City': '1087', 'TotalValue': '7420'}
# {'City': '1088', 'TotalValue': '7447'}
# {'City': '1089', 'TotalValue': '7458'}
# {'City': '1090', 'TotalValue': '7482'}
# {'City': '1091', 'TotalValue': '7487'}
# {'City': '1092', 'TotalValue': '7487'}
# {'City': '1093', 'TotalValue': '7497'}
# {'City': '1094', 'TotalValue': '7499'}
# {'City': '1095', 'TotalValue': '7511'}
# {'City': '1096', 'TotalValue': '7544'}
# {'City': '1097', 'TotalValue': '7545'}
# {'City': '1098', 'TotalValue': '7569'}
# {'City': '1099', 'TotalValue': '7575'}
# {'City': '1100', 'TotalValue': '7577'}
# {'City': '1101', 'TotalValue': '7590'}
# {'City': '1102', 'TotalValue': '7590'}
# {'City': '1103', 'TotalValue': '7591'}
# {'City': '1104', 'TotalValue': '7595'}
# {'City': '1105', 'TotalValue': '7597'}
# {'City': '1106', 'TotalValue': '7601'}
# {'City': '1107', 'TotalValue': '7609'}
# {'City': '1108', 'TotalValue': '7617'}
# {'City': '1109', 'TotalValue': '7619'}
# {'City': '1110', 'TotalValue': '7627'}
# {'City': '1111', 'TotalValue': '7674'}
# {'City': '1112', 'TotalValue': '5731'}
# {'City': '1113', 'TotalValue': '5732'}
# {'City': '1114', 'TotalValue': '5733'}
# {'City': '1115', 'TotalValue': '5734'}
# {'City': '1116', 'TotalValue': '5735'}
# {'City': '1117', 'TotalValue': '5736'}
# {'City': '1118', 'TotalValue': '5738'}
# {'City': '1119', 'TotalValue': '5742'}
# {'City': '1120', 'TotalValue': '5749'}
# {'City': '1121', 'TotalValue': '5750'}
# {'City': '1122', 'TotalValue': '5752'}
# {'City': '1123', 'TotalValue': '5757'}
# {'City': '1124', 'TotalValue': '5757'}
# {'City': '1125', 'TotalValue': '5758'}
# {'City': '1126', 'TotalValue': '5763'}
# {'City': '1127', 'TotalValue': '5769'}
# {'City': '1128', 'TotalValue': '5774'}
# {'City': '1129', 'TotalValue': '5779'}
# {'City': '1130', 'TotalValue': '5809'}
# {'City': '1131', 'TotalValue': '5809'}
# {'City': '1132', 'TotalValue': '5820'}
# {'City': '1133', 'TotalValue': '5833'}
# {'City': '1134', 'TotalValue': '5839'}
# {'City': '1135', 'TotalValue': '5850'}
# {'City': '1136', 'TotalValue': '5872'}
# {'City': '1137', 'TotalValue': '5886'}
# {'City': '1138', 'TotalValue': '5903'}
# {'City': '1139', 'TotalValue': '7688'}
# {'City': '1140', 'TotalValue': '7690'}
# {'City': '1141', 'TotalValue': '7701'}
# {'City': '1142', 'TotalValue': '7718'}
# {'City': '1143', 'TotalValue': '7728'}
# {'City': '1144', 'TotalValue': '7745'}
# {'City': '1145', 'TotalValue': '7750'}
# {'City': '1146', 'TotalValue': '7754'}
# {'City': '1147', 'TotalValue': '7759'}
# ...
# {'City': '4335', 'TotalValue': '27170'}
# {'City': '4336', 'TotalValue': '27173'}
# {'City': '4337', 'TotalValue': '27174'}
# {'City': '4338', 'TotalValue': '27176'}
# {'City': '4339', 'TotalValue': '27178'}
# {'City': '4340', 'TotalValue': '27180'}
# {'City': '4341', 'TotalValue': '27182'}
# {'City': '4342', 'TotalValue': '27183'}
# {'City': '4343', 'TotalValue': '27184'}
# {'City': '4344', 'TotalValue': '27185'}
# {'City': '4345', 'TotalValue': '27186'}
# {'City': '4346', 'TotalValue': '27188'}
# {'City': '4347', 'TotalValue': '27190'}
# {'City': '4348', 'TotalValue': '27193'}
# {'City': '4349', 'TotalValue': '27195'}
# {'City': '4350', 'TotalValue': '27196'}
# {'City': '4351', 'TotalValue': '27199'}
# {'City': '4352', 'TotalValue': '27200'}
# {'City': '4353', 'TotalValue': '27202'}
# {'City': '4354', 'TotalValue': '27205'}
# {'City': '4355', 'TotalValue': '27210'}
# {'City': '4356', 'TotalValue': '27061'}
# {'City': '4357', 'TotalValue': '27063'}
# {'City': '4358', 'TotalValue': '27068'}
# {'City': '4359', 'TotalValue': '27070'}
# {'City': '4360', 'TotalValue': '27072'}
# {'City': '4361', 'TotalValue': '27075'}
# {'City': '4362', 'TotalValue': '27076'}
# {'City': '4363', 'TotalValue': '27077'}
# {'City': '4364', 'TotalValue': '27079'}
# {'City': '4365', 'TotalValue': '27084'}
# {'City': '4366', 'TotalValue': '27086'}
# {'City': '4367', 'TotalValue': '27088'}
# {'City': '4368', 'TotalValue': '27089'}
# {'City': '4369', 'TotalValue': '27093'}
# {'City': '4370', 'TotalValue': '27094'}
# {'City': '4371', 'TotalValue': '27095'}
# {'City': '4372', 'TotalValue': '27103'}
# {'City': '4373', 'TotalValue': '27105'}
# {'City': '4374', 'TotalValue': '27106'}
# {'City': '4375', 'TotalValue': '27108'}
# {'City': '4376', 'TotalValue': '27110'}
# {'City': '4377', 'TotalValue': '27113'}
# {'City': '4378', 'TotalValue': '27116'}
# {'City': '4379', 'TotalValue': '27118'}
# {'City': '4380', 'TotalValue': '27119'}
# {'City': '4381', 'TotalValue': '27121'}
# {'City': '4382', 'TotalValue': '27122'}
# {'City': '4383', 'TotalValue': '27125'}
# {'City': '4384', 'TotalValue': '27126'}
# {'City': '4385', 'TotalValue': '27128'}
# {'City': '4386', 'TotalValue': '27129'}
# {'City': '4387', 'TotalValue': '27131'}
# {'City': '4388', 'TotalValue': '27132'}
# {'City': '4389', 'TotalValue': '27134'}
# {'City': '4390', 'TotalValue': '27137'}
# {'City': '4391', 'TotalValue': '27139'}
# {'City': '4392', 'TotalValue': '27141'}
# {'City': '4393', 'TotalValue': '27145'}
# {'City': '4394', 'TotalValue': '27146'}
# {'City': '4395', 'TotalValue': '27148'}
# {'City': '4396', 'TotalValue': '27149'}
# {'City': '4397', 'TotalValue': '27150'}
# {'City': '4398', 'TotalValue': '27154'}
# {'City': '4399', 'TotalValue': '27157'}
# {'City': '4400', 'TotalValue': '27158'}
# {'City': '4401', 'TotalValue': '27159'}
# {'City': '4402', 'TotalValue': '27160'}
# {'City': '4403', 'TotalValue': '27161'}
# {'City': '4404', 'TotalValue': '27162'}
# {'City': '4405', 'TotalValue': '27164'}
# {'City': '4406', 'TotalValue': '27215'}
# {'City': '4407', 'TotalValue': '27216'}
# {'City': '4408', 'TotalValue': '27217'}
# {'City': '4409', 'TotalValue': '27218'}
# {'City': '4410', 'TotalValue': '27220'}
# {'City': '4411', 'TotalValue': '27221'}
# {'City': '4412', 'TotalValue': '27228'}
# {'City': '4413', 'TotalValue': '27229'}
# {'City': '4414', 'TotalValue': '27235'}
# {'City': '4415', 'TotalValue': '27237'}
# {'City': '4416', 'TotalValue': '27238'}
# {'City': '4417', 'TotalValue': '27241'}
# {'City': '4418', 'TotalValue': '27242'}
# {'City': '4419', 'TotalValue': '27245'}
# {'City': '4420', 'TotalValue': '27246'}
# {'City': '4421', 'TotalValue': '27342'}
# {'City': '4422', 'TotalValue': '27343'}
# {'City': '4423', 'TotalValue': '27345'}
# {'City': '4424', 'TotalValue': '27346'}
# {'City': '4425', 'TotalValue': '27347'}
# {'City': '4426', 'TotalValue': '27349'}
# {'City': '4427', 'TotalValue': '27350'}
# {'City': '4428', 'TotalValue': '27351'}
# {'City': '4429', 'TotalValue': '27352'}
# {'City': '4430', 'TotalValue': '27353'}
# {'City': '4431', 'TotalValue': '27354'}
# {'City': '4432', 'TotalValue': '27166'}
# {'City': '4433', 'TotalValue': '27167'}
# {'City': '4434', 'TotalValue': '27168'}
# {'City': '4435', 'TotalValue': '27171'}
# {'City': '4436', 'TotalValue': '27172'}
# {'City': '4437', 'TotalValue': '27175'}
# {'City': '4438', 'TotalValue': '27177'}
# {'City': '4439', 'TotalValue': '27179'}
# {'City': '4440', 'TotalValue': '27181'}
# {'City': '4441', 'TotalValue': '27187'}
# {'City': '4442', 'TotalValue': '27189'}
# {'City': '4443', 'TotalValue': '27191'}
# {'City': '4444', 'TotalValue': '27192'}
# {'City': '4445', 'TotalValue': '27194'}
# {'City': '4446', 'TotalValue': '27197'}
# {'City': '4447', 'TotalValue': '27198'}
# {'City': '4448', 'TotalValue': '27201'}
# {'City': '4449', 'TotalValue': '27203'}
# {'City': '4450', 'TotalValue': '27204'}
# {'City': '4451', 'TotalValue': '27206'}
# {'City': '4452', 'TotalValue': '27207'}
# {'City': '4453', 'TotalValue': '27208'}
# {'City': '4454', 'TotalValue': '27209'}
# {'City': '4455', 'TotalValue': '27211'}
# {'City': '4456', 'TotalValue': '27212'}
# {'City': '4457', 'TotalValue': '27355'}
# {'City': '4458', 'TotalValue': '27479'}
# {'City': '4459', 'TotalValue': '27481'}
# {'City': '4460', 'TotalValue': '28005'}
# {'City': '4461', 'TotalValue': '28006'}
# {'City': '4462', 'TotalValue': '28007'}
# {'City': '4463', 'TotalValue': '28008'}
# {'City': '4464', 'TotalValue': '28010'}
# {'City': '4465', 'TotalValue': '28190'}
# {'City': '4466', 'TotalValue': '28193'}
# {'City': '4467', 'TotalValue': '28194'}
# {'City': '4468', 'TotalValue': '28195'}
# {'City': '4469', 'TotalValue': '28198'}
# {'City': '4470', 'TotalValue': '28199'}
# {'City': '4471', 'TotalValue': '28200'}
# {'City': '4472', 'TotalValue': '28204'}
# {'City': '4473', 'TotalValue': '28207'}
# {'City': '4474', 'TotalValue': '28208'}
# {'City': '4475', 'TotalValue': '28213'}
# {'City': '4476', 'TotalValue': '28215'}
# {'City': '4477', 'TotalValue': '28216'}
# {'City': '4478', 'TotalValue': '28452'}
# {'City': '4479', 'TotalValue': '28453'}
# {'City': '4480', 'TotalValue': '28454'}
# {'City': '4481', 'TotalValue': '28455'}
# {'City': '4482', 'TotalValue': '28456'}
# {'City': '4483', 'TotalValue': '27213'}
# {'City': '4484', 'TotalValue': '27214'}
# {'City': '4485', 'TotalValue': '27219'}
# {'City': '4486', 'TotalValue': '27222'}
# {'City': '4487', 'TotalValue': '27223'}
# {'City': '4488', 'TotalValue': '27224'}
# {'City': '4489', 'TotalValue': '27225'}
# {'City': '4490', 'TotalValue': '27226'}
# {'City': '4491', 'TotalValue': '27227'}
# {'City': '4492', 'TotalValue': '27231'}
# {'City': '4493', 'TotalValue': '27236'}
# {'City': '4494', 'TotalValue': '27239'}
# {'City': '4495', 'TotalValue': '27240'}
# {'City': '4496', 'TotalValue': '27243'}
# {'City': '4497', 'TotalValue': '27244'}
# {'City': '4498', 'TotalValue': '27340'}
# {'City': '4499', 'TotalValue': '27341'}
# {'City': '4500', 'TotalValue': '27344'}
# {'City': '4501', 'TotalValue': '27348'}
# {'City': '4502', 'TotalValue': '27356'}
# {'City': '4503', 'TotalValue': '27463'}
# {'City': '4504', 'TotalValue': '27480'}
# {'City': '4505', 'TotalValue': '28001'}
# {'City': '4506', 'TotalValue': '28002'}
# {'City': '4507', 'TotalValue': '28003'}
# {'City': '4508', 'TotalValue': '28004'}
# {'City': '4509', 'TotalValue': '28457'}
# {'City': '4510', 'TotalValue': '28459'}
# {'City': '4511', 'TotalValue': '28473'}
# {'City': '4512', 'TotalValue': '28474'}
# {'City': '4513', 'TotalValue': '28476'}
# {'City': '4514', 'TotalValue': '28478'}
# {'City': '4515', 'TotalValue': '28481'}
# {'City': '4516', 'TotalValue': '28482'}
# {'City': '4517', 'TotalValue': '28485'}
# {'City': '4518', 'TotalValue': '28488'}
# {'City': '4519', 'TotalValue': '28491'}
# {'City': '4520', 'TotalValue': '28492'}
# {'City': '4521', 'TotalValue': '28493'}
# {'City': '4522', 'TotalValue': '28495'}
# {'City': '4523', 'TotalValue': '28632'}
# {'City': '4524', 'TotalValue': '28633'}
# {'City': '4525', 'TotalValue': '28634'}
# {'City': '4526', 'TotalValue': '28635'}
# {'City': '4527', 'TotalValue': '28639'}
# {'City': '4528', 'TotalValue': '28640'}
# {'City': '4529', 'TotalValue': '28642'}
# {'City': '4530', 'TotalValue': '28646'}
# {'City': '4531', 'TotalValue': '28648'}
# {'City': '4532', 'TotalValue': '28649'}
# {'City': '4533', 'TotalValue': '28651'}
# {'City': '4534', 'TotalValue': '28009'}
# {'City': '4535', 'TotalValue': '28011'}
# {'City': '4536', 'TotalValue': '28189'}
# {'City': '4537', 'TotalValue': '28191'}
# {'City': '4538', 'TotalValue': '28192'}
# {'City': '4539', 'TotalValue': '28196'}
# {'City': '4540', 'TotalValue': '28197'}
# {'City': '4541', 'TotalValue': '28201'}
# {'City': '4542', 'TotalValue': '28202'}
# {'City': '4543', 'TotalValue': '28203'}
# {'City': '4544', 'TotalValue': '28205'}
# {'City': '4545', 'TotalValue': '28206'}
# {'City': '4546', 'TotalValue': '28209'}
# {'City': '4547', 'TotalValue': '28210'}
# {'City': '4548', 'TotalValue': '28211'}
# {'City': '4549', 'TotalValue': '28212'}
# {'City': '4550', 'TotalValue': '28214'}
# {'City': '4551', 'TotalValue': '28217'}
# {'City': '4552', 'TotalValue': '28218'}
# {'City': '4553', 'TotalValue': '28219'}
# {'City': '4554', 'TotalValue': '28220'}
# {'City': '4555', 'TotalValue': '28221'}
# {'City': '4556', 'TotalValue': '28458'}
# {'City': '4557', 'TotalValue': '28472'}
# {'City': '4558', 'TotalValue': '28475'}
# {'City': '4559', 'TotalValue': '28477'}
# {'City': '4560', 'TotalValue': '28676'}
# {'City': '4561', 'TotalValue': '28678'}
# {'City': '4562', 'TotalValue': '28679'}
# {'City': '4563', 'TotalValue': '28680'}
# {'City': '4564', 'TotalValue': '28687'}
# {'City': '4565', 'TotalValue': '28688'}
# {'City': '4566', 'TotalValue': '28689'}
# {'City': '4567', 'TotalValue': '28696'}
# {'City': '4568', 'TotalValue': '28697'}
# {'City': '4569', 'TotalValue': '28698'}
# {'City': '4570', 'TotalValue': '28699'}
# {'City': '4571', 'TotalValue': '28702'}
# {'City': '4572', 'TotalValue': '28704'}
# {'City': '4573', 'TotalValue': '28705'}
# {'City': '4574', 'TotalValue': '28707'}
# {'City': '4575', 'TotalValue': '28710'}
# {'City': '4576', 'TotalValue': '28711'}
# {'City': '4577', 'TotalValue': '28712'}
# {'City': '4578', 'TotalValue': '28713'}
# {'City': '4579', 'TotalValue': '28716'}
# {'City': '4580', 'TotalValue': '28717'}
# {'City': '4581', 'TotalValue': '28719'}
# {'City': '4582', 'TotalValue': '28720'}
# {'City': '4583', 'TotalValue': '28721'}
# {'City': '4584', 'TotalValue': '28722'}
# {'City': '4585', 'TotalValue': '28723'}
# {'City': '4586', 'TotalValue': '28724'}
# {'City': '4587', 'TotalValue': '28729'}
# {'City': '4588', 'TotalValue': '28734'}
# {'City': '4589', 'TotalValue': '28735'}
# {'City': '4590', 'TotalValue': '28736'}
# {'City': '4591', 'TotalValue': '28738'}
# {'City': '4592', 'TotalValue': '28739'}
# {'City': '4593', 'TotalValue': '28740'}
# {'City': '4594', 'TotalValue': '28741'}
# {'City': '4595', 'TotalValue': '28743'}
# {'City': '4596', 'TotalValue': '28744'}
# {'City': '4597', 'TotalValue': '28746'}
# {'City': '4598', 'TotalValue': '28748'}
# {'City': '4599', 'TotalValue': '28749'}
# {'City': '4600', 'TotalValue': '28751'}
# {'City': '4601', 'TotalValue': '28755'}
# {'City': '4602', 'TotalValue': '28756'}
# {'City': '4603', 'TotalValue': '28757'}
# {'City': '4604', 'TotalValue': '28758'}
# {'City': '4605', 'TotalValue': '28761'}
# {'City': '4606', 'TotalValue': '28766'}
# {'City': '4607', 'TotalValue': '28767'}
# {'City': '4608', 'TotalValue': '28769'}
# {'City': '4609', 'TotalValue': '28770'}
# {'City': '4610', 'TotalValue': '28771'}
# {'City': '4611', 'TotalValue': '28772'}
# {'City': '4612', 'TotalValue': '28479'}
# {'City': '4613', 'TotalValue': '28480'}
# {'City': '4614', 'TotalValue': '28483'}
# {'City': '4615', 'TotalValue': '28484'}
# {'City': '4616', 'TotalValue': '28486'}
# {'City': '4617', 'TotalValue': '28487'}
# {'City': '4618', 'TotalValue': '28489'}
# {'City': '4619', 'TotalValue': '28490'}
# {'City': '4620', 'TotalValue': '28494'}
# {'City': '4621', 'TotalValue': '28629'}
# {'City': '4622', 'TotalValue': '28636'}
# {'City': '4623', 'TotalValue': '28637'}
# {'City': '4624', 'TotalValue': '28638'}
# {'City': '4625', 'TotalValue': '28641'}
# {'City': '4626', 'TotalValue': '28643'}
# {'City': '4627', 'TotalValue': '28644'}
# {'City': '4628', 'TotalValue': '28645'}
# {'City': '4629', 'TotalValue': '28647'}
# {'City': '4630', 'TotalValue': '28677'}
# {'City': '4631', 'TotalValue': '28681'}
# {'City': '4632', 'TotalValue': '28682'}
# {'City': '4633', 'TotalValue': '28683'}
# {'City': '4634', 'TotalValue': '28684'}
# {'City': '4635', 'TotalValue': '28685'}
# {'City': '4636', 'TotalValue': '28686'}
# {'City': '4637', 'TotalValue': '28690'}
# {'City': '4638', 'TotalValue': '28775'}
# {'City': '4639', 'TotalValue': '28777'}
# {'City': '4640', 'TotalValue': '28778'}
# {'City': '4641', 'TotalValue': '28779'}
# {'City': '4642', 'TotalValue': '28780'}
# {'City': '4643', 'TotalValue': '28781'}
# {'City': '4644', 'TotalValue': '28785'}
# {'City': '4645', 'TotalValue': '28786'}
# {'City': '4646', 'TotalValue': '28788'}
# {'City': '4647', 'TotalValue': '28789'}
# {'City': '4648', 'TotalValue': '28792'}
# {'City': '4649', 'TotalValue': '28793'}
# {'City': '4650', 'TotalValue': '28794'}
# {'City': '4651', 'TotalValue': '28798'}
# {'City': '4652', 'TotalValue': '28801'}
# {'City': '4653', 'TotalValue': '28804'}
# {'City': '4654', 'TotalValue': '28805'}
# {'City': '4655', 'TotalValue': '28806'}
# {'City': '4656', 'TotalValue': '28807'}
# {'City': '4657', 'TotalValue': '28810'}
# {'City': '4658', 'TotalValue': '28811'}
# {'City': '4659', 'TotalValue': '28812'}
# {'City': '4660', 'TotalValue': '28815'}
# {'City': '4661', 'TotalValue': '28817'}
# {'City': '4662', 'TotalValue': '28819'}
# {'City': '4663', 'TotalValue': '28691'}
# {'City': '4664', 'TotalValue': '28692'}
# {'City': '4665', 'TotalValue': '28693'}
# {'City': '4666', 'TotalValue': '28694'}
# {'City': '4667', 'TotalValue': '28695'}
# {'City': '4668', 'TotalValue': '28700'}
# {'City': '4669', 'TotalValue': '28701'}
# {'City': '4670', 'TotalValue': '28703'}
# {'City': '4671', 'TotalValue': '28706'}
# {'City': '4672', 'TotalValue': '28708'}
# {'City': '4673', 'TotalValue': '28709'}
# {'City': '4674', 'TotalValue': '28714'}
# {'City': '4675', 'TotalValue': '28715'}
# {'City': '4676', 'TotalValue': '28718'}
# {'City': '4677', 'TotalValue': '28725'}
# {'City': '4678', 'TotalValue': '28726'}
# {'City': '4679', 'TotalValue': '28727'}
# {'City': '4680', 'TotalValue': '28728'}
# {'City': '4681', 'TotalValue': '28730'}
# {'City': '4682', 'TotalValue': '28731'}
# {'City': '4683', 'TotalValue': '28732'}
# {'City': '4684', 'TotalValue': '28733'}
# {'City': '4685', 'TotalValue': '28737'}
# {'City': '4686', 'TotalValue': '28742'}
# {'City': '4687', 'TotalValue': '28745'}
# {'City': '4688', 'TotalValue': '28747'}
# {'City': '4689', 'TotalValue': '28820'}
# {'City': '4690', 'TotalValue': '28834'}
# {'City': '4691', 'TotalValue': '28847'}
# {'City': '4692', 'TotalValue': '28852'}
# {'City': '4693', 'TotalValue': '28853'}
# {'City': '4694', 'TotalValue': '28859'}
# {'City': '4695', 'TotalValue': '28862'}
# {'City': '4696', 'TotalValue': '28750'}
# {'City': '4697', 'TotalValue': '28759'}
# {'City': '4698', 'TotalValue': '28760'}
# {'City': '4699', 'TotalValue': '28762'}
# {'City': '4700', 'TotalValue': '28763'}
# {'City': '4701', 'TotalValue': '28764'}
# {'City': '4702', 'TotalValue': '28765'}
# {'City': '4703', 'TotalValue': '28768'}
# {'City': '4704', 'TotalValue': '28773'}
# {'City': '4705', 'TotalValue': '28774'}
# {'City': '4706', 'TotalValue': '28776'}
# {'City': '4707', 'TotalValue': '28782'}
# {'City': '4708', 'TotalValue': '28783'}
# {'City': '4709', 'TotalValue': '28784'}
# {'City': '4710', 'TotalValue': '28787'}
# {'City': '4711', 'TotalValue': '28790'}
# {'City': '4712', 'TotalValue': '28791'}
# {'City': '4713', 'TotalValue': '28795'}
# {'City': '4714', 'TotalValue': '28796'}
# {'City': '4715', 'TotalValue': '28797'}
# {'City': '4716', 'TotalValue': '28799'}
# {'City': '4717', 'TotalValue': '28800'}
# {'City': '4718', 'TotalValue': '28802'}
# {'City': '4719', 'TotalValue': '28803'}
# {'City': '4720', 'TotalValue': '28808'}
# {'City': '4721', 'TotalValue': '28809'}
# {'City': '4722', 'TotalValue': '28813'}
# {'City': '4723', 'TotalValue': '28814'}
# {'City': '4724', 'TotalValue': '28816'}
# {'City': '4725', 'TotalValue': '28818'}
# {'City': '4726', 'TotalValue': '28833'}
# {'City': '4727', 'TotalValue': '28837'}
# {'City': '4728', 'TotalValue': '28843'}
# {'City': '4729', 'TotalValue': '28844'}
# {'City': '4730', 'TotalValue': '28848'}
# {'City': '4731', 'TotalValue': '28851'}
# {'City': '4732', 'TotalValue': '28857'}
# {'City': '4733', 'TotalValue': '28860'}
# {'City': '4734', 'TotalValue': '28861'}

# %%
# Required installations for Google Colab
# !pip install apache-beam

import apache_beam as beam

# Define the basic pipeline
def run_consolidated_pipeline():
    with beam.Pipeline() as pipeline:
        input_data = (
            pipeline
            | 'ReadCSV' >> beam.io.ReadFromText('/content/sample_data/real-estate-sales-730-days-1.csv', skip_header_lines=1)
            | 'ParseCSV' >> beam.Map(lambda line: dict(zip(['City', 'TotalValue'], line.split(','))))
            | 'WriteToCSV' >> beam.io.WriteToText('/content/sample_data/consolidated_output.csv', num_shards=1)
        )

run_consolidated_pipeline()
# Out:
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.10/dist-packages (2.51.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.9.9)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.8.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.59.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.74)
# Requirement already satisfied: numpy<1.25.0,>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.23.5)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.22.3)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.0,!=4.24.1,!=4.24.2,<4.25.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.21.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (9.0.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (5.1)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (2.7.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2023.7.22)

# %% [markdown]
# 1. **Setup**: We added necessary tools to work with our data.
# 2. **Average House Value**: We made a tool (function) that can calculate the average value of houses in a city.
# 3. **Date Conversion**: We made another tool that can read the date from our data. If the date is not correct, we just skip that piece of data.
# 4. **Main Process**:
#    - We opened and read our data from a file.
#    - We turned the data into a format that's easier for us to work with.
#    - We converted the date information for each house sale.
#    - We then grouped our data in chunks of 30 days (like putting them into monthly buckets).
#    - For each city, we made a list of house values.
#    - Using our average tool, we calculated the average house value for each city in each 30-day chunk.
#    - Lastly, we saved our results in a new file.
#
# In simpler terms, we looked at house sales data, grouped them by month and city, and then found out the average house sale value for each city in each month. We saved these monthly averages in a new file.

# %%
# Required installations for Google Colab
# !pip install apache-beam

import apache_beam as beam
from apache_beam.transforms.window import FixedWindows
from datetime import datetime

# Custom transformation to compute the average TotalValue for each city
class ComputeAverage(beam.DoFn):
    def process(self, element):
        city, total_values = element
        if total_values:
            avg_value = sum(total_values) / len(total_values)
            yield city, avg_value

# Convert string to datetime
def to_datetime(element):
    try:
        dt = datetime.strptime(element['Date'], '%Y-%m-%d %H:%M:%S')
        return beam.window.TimestampedValue(element, dt)
    except (ValueError, TypeError):
        return  # Skip rows with invalid dates

# Define the pipeline with windowing and ParDo
def run_advanced_pipeline():
    with beam.Pipeline() as pipeline:
        results = (
            pipeline
            | 'ReadCSV' >> beam.io.ReadFromText('/content/sample_data/real-estate-sales-730-days-1.csv', skip_header_lines=1)
            | 'ParseCSV' >> beam.Map(lambda line: dict(zip(['Date', 'City', 'TotalValue'], line.split(','))))
            | 'ToDatetime' >> beam.FlatMap(to_datetime)  # Convert string to datetime objects and filter out invalid entries
            | 'Window' >> beam.WindowInto(FixedWindows(30*24*60*60))  # 30 days in seconds
            | 'ToKV' >> beam.Map(lambda x: (x['City'], float(x['TotalValue'])))
            | 'GroupByKey' >> beam.GroupByKey()
            | 'ComputeAverage' >> beam.ParDo(ComputeAverage())
            | 'WriteResults' >> beam.io.WriteToText('/content/sample_data/windowed_output.csv', num_shards=1, header='City,AverageTotalValue')
        )

run_advanced_pipeline()
# Out:
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.10/dist-packages (2.51.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.9.9)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.8.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.59.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.74)
# Requirement already satisfied: numpy<1.25.0,>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.23.5)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.22.3)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.0,!=4.24.1,!=4.24.2,<4.25.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2023.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (0.21.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam) (9.0.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (5.1)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam) (2.7.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam) (2023.7.22)

# %%
# Define a basic pipeline to read, parse, and write the CSV data
def basic_pipeline():
    with beam.Pipeline() as pipeline:
        _ = (
            pipeline
            | 'ReadCSV' >> beam.io.ReadFromText('/content/sample_data/real-estate-sales-730-days-1.csv', skip_header_lines=1)
            | 'ParseCSV' >> beam.Map(lambda line: dict(zip(['Date', 'City', 'TotalValue'], line.split(','))))
            | 'WriteResults' >> beam.io.WriteToText('/content/sample_data/basic_output.csv', num_shards=1, header='Date,City,TotalValue')
        )

basic_pipeline()

# %% [markdown]
# We followed the steps below:
# 1. **Setup**: We set things up by downloading the necessary tools.
# 2. **Filter Houses**: We made a function to pick houses whose value is above a certain amount.
# 3. **Average by City**: We made another function to find out the average house value in each city.
# 4. **The Main Process**:
#    - We read the data from a file.
#    - We turned each line in the file into a dictionary with city names and house values.
#    - For debugging, we printed out the data to see if it looks right.
#    - We used our filter to keep only the houses we're interested in.
#    - Again, for debugging, we printed out the filtered data.
#    - We then calculated the average house value for each city.
#    - Finally, we saved our results to a new file.
#
# In simpler terms, we took a list of houses, filtered out the cheaper ones, and then found out the average value of the remaining houses in each city. We saved these average values in a new file.
