# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 70.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.0 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
import pandas as pd

# %%
# !pip install Jinja2
# !pip install markupsafe==2.0.1
# Out:
# ...
#   Using cached MarkupSafe-2.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# werkzeug 2.2.3 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af6e73ad-1a00-4e7e-ab6b-997e394a96fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af6e73ad-1a00-4e7e-ab6b-997e394a96fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pycaret.datasets import get_data
lang_data = get_data('train')
# Out:
#              cuneiform lang
# 0  𒃻𒋻𒃻𒍜𒋾𒅅𒅟𒈨𒌍𒃻𒇽𒍑𒆪𒈨𒌍𒌗𒋢𒈨𒌍  LTB
# 1         𒊹𒌋𒀀𒈨𒌍𒋙𒊹𒈪𒋻𒋾𒅅𒅟  LTB
# 2                𒊹𒀀𒃻𒊹𒊹  LTB
# 3                𒊹𒀀𒃻𒊹𒊹  LTB
# 4            𒊹𒌋𒊹𒀀𒈨𒌍𒃻𒊹𒈦  LTB

# %% [markdown]
# # Setup

# %%
from pycaret.classification import *
s = setup(lang_data, target = 'lang', session_id=123)
# Out:
# <style type="text/css">
# #T_8eff7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8eff7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eff7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8eff7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eff7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8eff7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8eff7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8eff7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8eff7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8eff7_row1_col1" class="data row1 col1" >lang</td>
#     </tr>
#     <tr>
#       <th id="T_8eff7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.classification import ClassificationExperiment
exp_multi = ClassificationExperiment()

# %%
type(exp_multi)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
from ast import expr_context
exp_multi.setup(lang_data, target='lang', session_id=123)
# Out:
# <style type="text/css">
# #T_90193_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_90193" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90193_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_90193_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90193_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90193_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_90193_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_90193_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90193_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_90193_row1_col1" class="data row1 col1" >lang</td>
#     </tr>
#     <tr>
#       <th id="T_90193_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Compare Models

# %%
train_model = compare_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f0702373f289> in <cell line: 1>()
# ----> 1 train_model = compare_models()
#
# NameError: name 'compare_models' is not defined

# %%
exp_multi.compare_models()
# Out:
# <style type="text/css">
# #T_57339 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # Analyze Model

# %%
plot_model(train_model, plot='confusion_matrix')

# %%
plot_model(train_model, plot='feature')

# %%
help(plot_model)
# Out:
# Help on function plot_model in module pycaret.classification.functional:
#
# plot_model(estimator, plot: str = 'auc', scale: float = 1, save: bool = False, fold: Union[int, Any, NoneType] = None, fit_kwargs: Optional[dict] = None, plot_kwargs: Optional[dict] = None, groups: Union[str, Any, NoneType] = None, verbose: bool = True, display_format: Optional[str] = None) -> Optional[str]
#     This function analyzes the performance of a trained model on holdout set.
#     It may require re-training the model in certain cases.
#
#     Example
#     -------
#     >>> from pycaret.datasets import get_data
#     >>> juice = get_data('juice')
#     >>> from pycaret.classification import *
#     >>> exp_name = setup(data = juice,  target = 'Purchase')
#     >>> lr = create_model('lr')
#     >>> plot_model(lr, plot = 'auc')
#
#
#     estimator: scikit-learn compatible object
#         Trained model object
#
#
#     plot: str, default = 'auc'
#         List of available plots (ID - Name):
#
# ...

# %%
evaluate_model(train_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Prediction Model

# %%
genre_ds = predict_model(train_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba940" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba940_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba940_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ba940_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ba940_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ba940_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ba940_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ba940_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ba940_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba940_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(train_model, plot='auc')

# %%
help(plot_model)
# Out:
# Help on function plot_model in module pycaret.classification.functional:
#
# plot_model(estimator, plot: str = 'auc', scale: float = 1, save: bool = False, fold: Union[int, Any, NoneType] = None, fit_kwargs: Optional[dict] = None, plot_kwargs: Optional[dict] = None, groups: Union[str, Any, NoneType] = None, verbose: bool = True, display_format: Optional[str] = None) -> Optional[str]
#     This function analyzes the performance of a trained model on holdout set.
#     It may require re-training the model in certain cases.
#
#     Example
#     -------
#     >>> from pycaret.datasets import get_data
#     >>> juice = get_data('juice')
#     >>> from pycaret.classification import *
#     >>> exp_name = setup(data = juice,  target = 'Purchase')
#     >>> lr = create_model('lr')
#     >>> plot_model(lr, plot = 'auc')
#
#
#     estimator: scikit-learn compatible object
#         Trained model object
#
#
#     plot: str, default = 'auc'
#         List of available plots (ID - Name):
#
# ...

# %%
evaluate_model(train_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Prediction

# %%
movie_prediction = predict_model(train_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_309c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_309c1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_309c1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_309c1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_309c1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_309c1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_309c1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_309c1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_309c1_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_309c1_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
movie_prediction.head()
# Out:
#                  cuneiform  lang prediction_label  prediction_score
# 31423       𒈠𒀀𒊭𒀸𒋫𒄷𒈨𒊭𒆳𒄷𒁍𒍑𒆠𒀀     2              NEA               0.4
# 99598               𒀀𒀊𒁀𒅆𒉏𒈠     6              SUX               1.0
# 97103               𒉌𒌓𒁓𒋗𒊩𒆷     6              NEA               0.4
# 25073  𒄿𒈾𒀭𒈾𒁹𒍝𒀠𒈬𒀀𒈾𒉺𒀭𒀀𒄭𒅀𒇷𒀉𒋼𒁉     1              NEA               0.4
# 84824                   𒇻𒇽     5              NEA               0.4

# %%
new_lang_data = lang_data.copy()
new_lang_data.drop('lang', axis =1, inplace = True)
new_lang_data.head()
# Out:
#              cuneiform
# 0  𒃻𒋻𒃻𒍜𒋾𒅅𒅟𒈨𒌍𒃻𒇽𒍑𒆪𒈨𒌍𒌗𒋢𒈨𒌍
# 1         𒊹𒌋𒀀𒈨𒌍𒋙𒊹𒈪𒋻𒋾𒅅𒅟
# 2                𒊹𒀀𒃻𒊹𒊹
# 3                𒊹𒀀𒃻𒊹𒊹
# 4            𒊹𒌋𒊹𒀀𒈨𒌍𒃻𒊹𒈦

# %%
predictions = predict_model(train_model, data= new_lang_data)
predictions.head()
# Out:
#              cuneiform prediction_label  prediction_score
# 0  𒃻𒋻𒃻𒍜𒋾𒅅𒅟𒈨𒌍𒃻𒇽𒍑𒆪𒈨𒌍𒌗𒋢𒈨𒌍              LTB               1.0
# 1         𒊹𒌋𒀀𒈨𒌍𒋙𒊹𒈪𒋻𒋾𒅅𒅟              NEA               0.4
# 2                𒊹𒀀𒃻𒊹𒊹              LTB               1.0
# 3                𒊹𒀀𒃻𒊹𒊹              LTB               1.0
# 4            𒊹𒌋𒊹𒀀𒈨𒌍𒃻𒊹𒈦              LTB               1.0

# %% [markdown]
# ### Save Model

# %%
#save pipeline
save_model(train_model, 'my_pipeline1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='...
#                                                                hierarchy=None,
# ...

# %%
#load pipeline
loaded_best_langpipeline = load_model('my_pipeline1')
loaded_best_langpipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='...
#                                                               hierarchy=None,
# ...
